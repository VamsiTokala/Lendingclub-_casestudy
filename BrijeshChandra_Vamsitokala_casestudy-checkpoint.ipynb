# %%
## import dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:/Users/adm_i32d/Documents/loan.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.shape
# Out:
# (39717, 111)

# %%
#delete columns with all null values
df1 = df.dropna(axis=1,how="all")

# %%
df1.shape
# Out:
# (39717, 57)

# %%
#Cleaning Data

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
#drop columns with missing values

# %%
df1=df1.drop(['policy_code','delinq_amnt','tax_liens','acc_now_delinq','chargeoff_within_12_mths','application_type'], axis=1)

# %%
#drop columns with no use
df1=df1.drop(['url','emp_title','issue_d','pymnt_plan','zip_code','earliest_cr_line','member_id','id'], axis=1)

# %%
df1=df1.drop(['out_prncp','out_prncp_inv'], axis=1)

# %%
df1=df1.drop(['collections_12_mths_ex_med'], axis=1)

# %%
df1.shape
# Out:
# (39717, 40)

# %% [markdown]
# df1["loan_status"].value_counts() #5627  defaulted out of 397177

# %%
#Univariate Analysis - Review the shortlisted columns

# %%
#Average Loan Amount is 10000

# %%
sns.boxplot( y=df1["loan_amnt"] )
plt.ylabel('Loan Amount')
plt.show()

# %%
sns.boxplot( y=customerDF["annual_inc"] )
plt.ylabel('Annual Income')
plt.show()

# %%
sns.countplot(x= customerDF["loan_status"])
plt.show()

# %%
#BIVARIATE Analysis

# %%
sns.countplot(x='loan_status', hue='home_ownership', data=customerDF)
plt.show()

# %%
sns.countplot(x='emp_length', hue='loan_status', data=customerDF)
plt.xlabel('Employee Experience')
plt.show()

# %%
sns.countplot(x='annual_inc', hue='loan_status', data=customerDF)
plt.xlabel('Annual Income')
plt.show()

# %%
sns.countplot(x='term', hue='loan_status', data=customerDF)
plt.xlabel('No of Terms')
plt.show()

# %%
#filter row which are defaulted

# %%
df1.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
plt.figure(figsize=(40,40))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
#filter rows which are defaulted
defaultDF=df1[df1['loan_status']=='Charged Off']

# %%
defaultDF.shape
# Out:
# (5627, 40)

# %%
defaultDF.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
sns.countplot(x='home_ownership',hue='loan_status', data=defaultDF)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,6)) 
sns.countplot(y='addr_state',hue='loan_status', data=defaultDF )
plt.subplots_adjust(bottom = 0.1)
plt.xlabel('loan status')
plt.ylabel('State')
plt.show()
